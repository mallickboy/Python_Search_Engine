# %%
import requests

def pipeline(query):

    # s1
    response = requests.get(f"http://192.168.1.3:4002/vectorizer?sentence={query}")
    response = response.json()  
    vector= response.get("vector",[])
    # print(len(vector))
    print(vector)

    # s2
    response = requests.get(f"http://192.168.1.3:4001/search?query_vector={vector}").json()
    print(response.keys())

pipeline("tuple")
# Out:
# [0.20624077320098877, -0.3429988622665405, -0.16825492680072784, -0.3196806013584137, -0.02447621338069439, 0.7515551447868347, -0.1989288628101349, 0.6332820653915405, -0.10442754626274109, 0.26005879044532776, 0.12453209608793259, -0.1036381796002388, -0.7637612819671631, 0.7233901619911194, 0.26419076323509216, -0.6446546912193298, -0.5449516177177429, 0.5495135188102722, 0.2777433693408966, 0.7917605638504028, 0.8159197568893433, 0.07024180144071579, 0.06658248603343964, -1.1494430303573608, 0.23212102055549622, -0.42775866389274597, 1.0787253379821777, -0.22871674597263336, 0.2838985323905945, 0.5390059351921082, -0.11761060357093811, 0.37193065881729126, -0.3921440839767456, -0.02367786318063736, -0.9474900364875793, 0.016667205840349197, 0.9777654409408569, 0.5793835520744324, -0.11046557128429413, 0.5569586753845215, 0.05976061895489693, 0.12509974837303162, 0.21085022389888763, -0.4612731337547302, -0.7439138293266296, -0.06396840512752533, -0.24359793961048126, 0.0153765678
# ...
